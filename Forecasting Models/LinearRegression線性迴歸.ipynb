# %% [markdown]
# # Linear Regression
# # 線性迴歸

# %% [markdown]
# Let's fabricate some data that shows a roughly linear relationship between page speed and amount purchased:
#
# 讓我們編造一些數據，顯示頁面速度和購買量之間的線性關係：

# %%
# %matplotlib inline
import numpy as np
from pylab import *

pageSpeeds = np.random.normal(3.0, 1.0, 1000)  # 平均3秒 標準差是1 
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 0.1, 1000)) * 3   # 消費金額

scatter(pageSpeeds, purchaseAmount);

# %% [markdown]
# As we only have two features, we can keep it simple and just use scipy.state.linregress:

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)
# stats.linregress()處理特徵

# %% [markdown]
# Not surprisngly, our R-squared value shows a really good fit:
#
# R 平方

# %%
r_value ** 2
# Out:
# 0.9896712781358801

# %% [markdown]
# Let's use the slope and intercept we got from the regression to plot predicted values vs. observed:
#
# 使用斜率和截距，從線性迴歸中得到的繪製預測值：

# %%
import matplotlib.pyplot as plt

def predict(x):
    return slope * x + intercept    # y = mx + b

fitLine = predict(pageSpeeds)

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='r')
plt.show()

# %% [markdown]
# ## Activity

# %% [markdown]
# Try increasing the random variation in the test data, and see what effect it has on the r-squared error value.
#
# 試著將測試資料隨機變動，看看有什麼影響

# %%
# %matplotlib inline
import numpy as np
from pylab import *

pageSpeeds = np.random.normal(3.0, 1.0, 1000)  # 平均3秒 標準差是1 
purchaseAmount = np.random.normal(3.0, 1.0, 1000) +  np.random.normal(3.0, 1.0, 1000) + pageSpeeds * 2.5   # 消費金額

scatter(pageSpeeds, purchaseAmount);

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

# %%
r_value ** 2
# Out:
# 0.770180594264084

# %%
import matplotlib.pyplot as plt

def predict(x):
    return slope * x + intercept    # y = mx + b

fitLine = predict(pageSpeeds)

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='r')
plt.show()
