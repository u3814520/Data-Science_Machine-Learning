# %% [markdown]
# # Data Distributions
# # 資料分佈範例

# %% [markdown]
# ## Uniform Distribution
# ## 均勻分佈
# 產生一個均勻分佈的隨機值，範圍-10到10，數量為100000個，並建立直方圖:

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

values = np.random.uniform(-10.0, 10.0, 100000)
plt.hist(values, 50)
plt.show()

# %% [markdown]
# ## Normal / Gaussian
# ## 常態分佈/高斯分佈

# %% [markdown]
# Visualize the probability density function:
#
# 用arange建立一個x串列，範圍-3到3之間，增量為0.001 (x為串列值，y常態分佈函數)
#
# 常態分佈的機率密度函數值:

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt

x = np.arange(-3, 3, 0.001)
plt.plot(x, norm.pdf(x));

# %% [markdown]
# Generate some random numbers with a normal distribution. "mu" is the desired mean, "sigma" is the standard deviation:
#
# 生成一個常態分佈的隨機數據。"mu"是平均數，"sigma"是標準偏差：

# %%
import numpy as np
import matplotlib.pyplot as plt

mu = 5.0
sigma = 2.0
values = np.random.normal(mu, sigma, 10000)
plt.hist(values, 50)
plt.show()

# %% [markdown]
# ## Exponential PDF / "Power Law"
# ## 指數機率分佈/冪定律
# 用arange建立一個x串列，範圍0到10之間，間隔為0.001
#
# y由expon.pdf(x)產生:

# %%
from scipy.stats import expon
import matplotlib.pyplot as plt

x = np.arange(0, 10, 0.001)
plt.plot(x, expon.pdf(x));

# %% [markdown]
# ## Binomial Probability Mass Function
# ## 二項式分佈 與 質量函數
# 建立一個離散數值x，範圍0到10之間，間隔為0.001，繪製二項式分佈:
#
# binom函數中，用n和p設定資料形狀，分別為10和0.5

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt

n, p = 10, 0.5
x = np.arange(0, 10, 0.001)
plt.plot(x, binom.pmf(x, n, p));

# %% [markdown]
# ## Poisson Probability Mass Function
# ## 卜瓦松分佈 與 質量函數
# 卜瓦松分佈:預測未來某個時間該事件發生特定次數的機率

# %% [markdown]
# 假設一個網站，每天的平均訪客數是500人次，那某一天訪客數為550人次的機率是多少?

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt

mu = 500                             # 平均數
x = np.arange(400, 600, 0.5)         # 範圍400到600 間隔0.5
plt.plot(x, poisson.pmf(x, mu));

# %% [markdown]
# 如上圖，某一天訪客數為550人次的機率是0.002

# %% [markdown]
# ## Pop Quiz!
# ## 測驗!

# %% [markdown]
# What's the equivalent of a probability distribution function when using discrete instead of continuous data?
#
# 使用離散數據而不是連續數據時，概率分佈函數的等價物是什麼？

# %% [markdown]
# 答:機率密度函數是用於處理連續型資料，機率質量函數則用於處理離散型資料。
